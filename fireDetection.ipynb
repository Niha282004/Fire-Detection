# %%
# !pip install ultralytics
# !pip install roboflow

# %%
import ultralytics
from roboflow import Roboflow
from ultralytics import YOLO
from IPython.display import Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="tXkJaC0z7OFUrU13iRGy")
project = rf.workspace("-jwzpw").project("continuous_fire")
version = project.version(6)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to continuous_fire-6 in yolov8:: 100%|██████████| 5030/5030 [00:00<00:00, 5889.65it/s]

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/content/continuous_fire-6/data.yaml epochs=10 imgsz=640 plots=True
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 250MB/s]
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
resultData = "/content/runs/detect/train/"
from IPython.display import Image, display

Image(filename =f'{resultData}confusion_matrix.png')

# %%
# VIEW MODEL TRANING CHARTS
Image(filename=f'/content/runs/detect/train/results.png', width=600)

# %%
# VALIDATION
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data=/content/continuous_fire-6/data.yaml
# Out:
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/continuous_fire-6/valid/labels.cache... 754 images, 2 backgrounds, 0 corrupt: 100% 754/754 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 48/48 [00:11<00:00,  4.34it/s]
#                    all        754        950      0.754      0.786      0.806      0.549
# Speed: 0.6ms preprocess, 8.7ms inference, 0.0ms loss, 1.7ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %%
import os
os.chdir("/content")
# %pwd
# Out:
# '/content'

# %%
# !mkdir ManualTestingData

# %%
os.chdir("/content/ManualTestingData")
# %pwd
# Out:
# '/content/ManualTestingData'

# %%
URL = "https://drive.google.com/file/d/1Hsw32IDOg4kAP_oOniknjzMUBPdfviuY/view?usp=sharing"
id = "1Hsw32IDOg4kAP_oOniknjzMUBPdfviuY"
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1Hsw32IDOg4kAP_oOniknjzMUBPdfviuY' -O test.jpg
# Out:
# --2025-01-15 11:06:55--  https://docs.google.com/uc?export=download&id=1Hsw32IDOg4kAP_oOniknjzMUBPdfviuY
# Resolving docs.google.com (docs.google.com)... 142.251.2.100, 142.251.2.113, 142.251.2.138, ...
# Connecting to docs.google.com (docs.google.com)|142.251.2.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1Hsw32IDOg4kAP_oOniknjzMUBPdfviuY&export=download [following]
# --2025-01-15 11:06:55--  https://drive.usercontent.google.com/download?id=1Hsw32IDOg4kAP_oOniknjzMUBPdfviuY&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0b::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 196699 (192K) [image/jpeg]
# Saving to: ‘test.jpg’
#
# ...

# %%
URL = "https://drive.google.com/file/d/1IBwmDh9SJkpHZPWPK8zciJep8v4N744C/view?usp=sharing"
id = "1IBwmDh9SJkpHZPWPK8zciJep8v4N744C"
# !wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1IBwmDh9SJkpHZPWPK8zciJep8v4N744C' -O test2.jpg
# Out:
# --2025-01-15 11:07:04--  https://docs.google.com/uc?export=download&id=1IBwmDh9SJkpHZPWPK8zciJep8v4N744C
# Resolving docs.google.com (docs.google.com)... 142.251.2.100, 142.251.2.113, 142.251.2.138, ...
# Connecting to docs.google.com (docs.google.com)|142.251.2.100|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1IBwmDh9SJkpHZPWPK8zciJep8v4N744C&export=download [following]
# --2025-01-15 11:07:04--  https://drive.usercontent.google.com/download?id=1IBwmDh9SJkpHZPWPK8zciJep8v4N744C&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 142.251.2.132, 2607:f8b0:4023:c0b::84
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|142.251.2.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 35983 (35K) [image/jpeg]
# Saving to: ‘test2.jpg’
#
# ...

# %%
weightsPath= "/content/runs/detect/train/weights"

# !yolo task=detect mode=predict model={weightsPath}/best.pt conf=.5 source='test.jpg' save=True
# Out:
# Ultralytics 8.3.61 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,125,971 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/1 /content/ManualTestingData/test.jpg: 448x640 1 fire, 37.8ms
# Speed: 3.3ms preprocess, 37.8ms inference, 684.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# https://drive.google.com/file/d/1Hsw32IDOg4kAP_oOniknjzMUBPdfviuY/view?usp=sharing
#
# https://drive.google.com/file/d/1IBwmDh9SJkpHZPWPK8zciJep8v4N744C/view?usp=sharing
